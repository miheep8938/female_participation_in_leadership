# %%
import os
from glob import glob
from os import chdir
import pandas as pd

# %%
csv_file_path = 'c:/Users/jgj81/Desktop/Homework/female_participation_in_leadership/Resources/States_Data'
chdir(csv_file_path)

# %%
file_pattern = "csv"
all_filenames = [file for file in glob('*.{}'.format(file_pattern))]
print(all_filenames)
# Out:
# ['2010_census.csv', '2011_census.csv', '2012_census.csv', '2013_census.csv', '2014_census.csv', '2015_census.csv', '2016_census.csv', '2017_census.csv', '2018_census.csv', '2019_census.csv']

# %%
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
#export to csv
combined_csv.to_csv( "merged_states.csv", index=False, encoding='utf-8-sig')

# %%
states_data = pd.read_csv('c:/Users/jgj81/Desktop/Homework/female_participation_in_leadership/Resources/States_Data/merged_states.csv')

states_data
# Out:
#      Year                                              Label     US_Total  \
# 0    2010     Civilian employed population 16 years and over  139,033,928
# 1    2010  Management, business, science, and arts occupa...   49,975,620
# 2    2010      Management, business, and financial occupa...   19,970,732
# 3    2010                             Management occupations   13,446,602
# 4    2010          Business and financial operations occu...    6,524,130
# ..    ...                                                ...          ...
# 355  2019          Installation, maintenance, and repair ...    4,862,879
# 356  2019      Production, transportation, and material m...   21,001,720
# 357  2019                             Production occupations    8,871,933
# 358  2019                         Transportation occupations    6,260,219
# 359  2019                        Material moving occupations    5,869,568
#
#     US_Male_Percent US_Female_Percent US_Total_Median_Earnings   \
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
gender_parity = pd.read_csv('Resources/States_Data/gender_parity_index_2020.csv')
gender_parity.head()
# Out:
#            State  Ranking 1993   Points 1993 Grades 1993  Ranking 2003  \
# 0  New Hampshire             16        13.27           D            11
# 1     Washington              8        17.67           D             4
# 2         Hawaii             29         8.91           F             6
# 3     California              3        23.59           D             1
# 4        Arizona             12        15.34           D             3
#
#    Points 2003 Grades 2003  Ranking 2014  Points 2014 Grades 2014  ...  \
# 0        20.88           D             1        47.45           B  ...
# 1        28.93           C             2        42.48           B  ...
# 2        26.33           C             3        39.58           B  ...
# 3        36.13           B             4        34.12           B  ...
# 4        29.06           C             5        33.83           B  ...
#
#    Grades 2017  Ranking 2018 Points 2018  Grades 2018  Ranking 2019  \
# ...

# %%
gender_parity.dtypes
# Out:
# State             object
# Ranking 1993       int64
# Points 1993      float64
# Grades 1993       object
# Ranking 2003       int64
# Points 2003      float64
# Grades 2003       object
# Ranking 2014       int64
# Points 2014      float64
# Grades 2014       object
# Ranking 2015       int64
# Points 2015      float64
# Grades 2015       object
# Ranking 2016       int64
# Points 2016      float64
# Grades 2016       object
# Ranking 2017       int64
# Points 2017      float64
# Grades 2017       object
# Ranking 2018       int64
# Points 2018      float64
# Grades 2018       object
# Ranking 2019       int64
# Points 2019      float64
# Grades 2019       object
# Ranking 2020       int64
# Points 2020      float64
# Grades 2020       object
# dtype: object

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
df_merge_all = pd.read_csv('Resources/World_Data/international_wage_gap_data.csv')
df_merge_all
# Out:
#      Unnamed: 0  Latitude  Longitude      Country Location   SUBJECT  Time  \
# 0             0   35.6897   139.6922        Japan      JPN  EMPLOYEE  2000
# 1             1   35.6897   139.6922        Japan      JPN  EMPLOYEE  2001
# 2             2   35.6897   139.6922        Japan      JPN  EMPLOYEE  2002
# 3             3   35.6897   139.6922        Japan      JPN  EMPLOYEE  2003
# 4             4   35.6897   139.6922        Japan      JPN  EMPLOYEE  2004
# ..          ...       ...        ...          ...      ...       ...   ...
# 388         388   46.9480     7.4474  Switzerland      CHE  EMPLOYEE  2010
# 389         389   46.9480     7.4474  Switzerland      CHE  EMPLOYEE  2012
# 390         390   46.9480     7.4474  Switzerland      CHE  EMPLOYEE  2014
# 391         391   46.9480     7.4474  Switzerland      CHE  EMPLOYEE  2016
# 392         392   46.9480     7.4474  Switzerland      CHE  EMPLOYEE  2018
#
#      WageGap
# 0      33.86
# 1      33.86
# 2      32.53
# ...

# %%
index = df_merge_all.set_index('Country')
index
# Out:
#              Unnamed: 0  Latitude  Longitude Location   SUBJECT  Time  WageGap
# Country
# Japan                 0   35.6897   139.6922      JPN  EMPLOYEE  2000    33.86
# Japan                 1   35.6897   139.6922      JPN  EMPLOYEE  2001    33.86
# Japan                 2   35.6897   139.6922      JPN  EMPLOYEE  2002    32.53
# Japan                 3   35.6897   139.6922      JPN  EMPLOYEE  2003    32.00
# Japan                 4   35.6897   139.6922      JPN  EMPLOYEE  2004    31.09
# ...                 ...       ...        ...      ...       ...   ...      ...
# Switzerland         388   46.9480     7.4474      CHE  EMPLOYEE  2010    20.05
# Switzerland         389   46.9480     7.4474      CHE  EMPLOYEE  2012    19.34
# Switzerland         390   46.9480     7.4474      CHE  EMPLOYEE  2014    16.94
# Switzerland         391   46.9480     7.4474      CHE  EMPLOYEE  2016    14.76
# Switzerland         392   46.9480     7.4474      CHE  EMPLOYEE  2018    15.10
#
# ...

# %%
# drop _id column
index.drop(columns =['Unnamed: 0','Latitude','Longitude','Location','SUBJECT'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-292dd0709d16> in <module>
#       1 # drop _id column
# ----> 2 index.drop(columns =['Unnamed: 0','Latitude','Longitude','Location','SUBJECT'], axis=1)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4172             level=level,
#    4173             inplace=inplace,
# -> 4174             errors=errors,
#    4175         )
#    4176
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3887         for axis, labels in axes.items():
#    3888             if labels is not None:
# -> 3889                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3890
#    3891         if inplace:
#
# ...

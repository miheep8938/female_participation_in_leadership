# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
merged_ = pd.read_csv('Resources/World_Data/international_wage_gap_data.csv')
df_merge_all
# Out:
#      Unnamed: 0  Latitude  Longitude      Country Location   SUBJECT  Time  \
# 0             0   35.6897   139.6922        Japan      JPN  EMPLOYEE  2000
# 1             1   35.6897   139.6922        Japan      JPN  EMPLOYEE  2001
# 2             2   35.6897   139.6922        Japan      JPN  EMPLOYEE  2002
# 3             3   35.6897   139.6922        Japan      JPN  EMPLOYEE  2003
# 4             4   35.6897   139.6922        Japan      JPN  EMPLOYEE  2004
# ..          ...       ...        ...          ...      ...       ...   ...
# 388         388   46.9480     7.4474  Switzerland      CHE  EMPLOYEE  2010
# 389         389   46.9480     7.4474  Switzerland      CHE  EMPLOYEE  2012
# 390         390   46.9480     7.4474  Switzerland      CHE  EMPLOYEE  2014
# 391         391   46.9480     7.4474  Switzerland      CHE  EMPLOYEE  2016
# 392         392   46.9480     7.4474  Switzerland      CHE  EMPLOYEE  2018
#
#      WageGap
# 0      33.86
# 1      33.86
# 2      32.53
# ...
